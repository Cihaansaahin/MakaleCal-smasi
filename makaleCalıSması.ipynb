# %%
from googleapiclient.discovery import build
from textblob import TextBlob  # TextBlob'u import ettik

# API anahtarınızı buraya ekleyin
api_key = "AIzaSyC_ybONJ0lbnPg6Lmt5N6vdRoTc6C9jB4A"
youtube = build('youtube', 'v3', developerKey=api_key)

# Yorumlarını çekmek istediğiniz video ID'si
video_id = "0_fDiwCTJwc"

# Yorumları almak
request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,
    maxResults=100
)
response = request.execute()

# Yorumların duygu analizi
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    
    # TextBlob ile duygu analizi
    blob = TextBlob(comment)
    sentiment = blob.sentiment.polarity  # Polarity: -1 (negatif) to 1 (pozitif)
    
    if sentiment > 0:
        sentiment_label = 'Pozitif'
    elif sentiment < 0:
        sentiment_label = 'Negatif'
    else:
        sentiment_label = 'Nötr'
    
    print(f"Yorum: {comment}\nDuygu: {sentiment_label}\n")
# Out:
# Yorum: Great content, some times being specific  is better than being massive
# Duygu: Pozitif
#
# Yorum: Thank you so much, this is gold, hope you have a good day!!
# Duygu: Pozitif
#
# Yorum: Dude, this video is fantastic. This is so helpful and instills me with optimism. Thank you
# Duygu: Pozitif
#
# Yorum: can anyone tell me how much time i required to be blockchain dev??
# Duygu: Pozitif
#
# Yorum: you’re and excellent teacher. The difference between learning and failing in my opinion, is to have an excellent teacher. You seem like you are  an excellent teacher.
# Duygu: Pozitif
#
# ...
